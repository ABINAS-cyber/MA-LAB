# %%
import pandas as pd

a = ["Abinas", "E", 9.14]
s = pd.Series(a, index=["Name", "Section", "Gpa"])

print(s)
print()
print(s.index)
print(s.values)
# Out:
# Name       Abinas
# Section         E
# Gpa          9.14
# dtype: object
#
# Index(['Name', 'Section', 'Gpa'], dtype='object')
# ['Abinas' 'E' 9.14]
